# %%
import os
import numpy as np
import pandas as pd
import xgboost as xgb
import seaborn as sns
from sklearn.metrics import mean_squared_error
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### データ読込

# %%
in_dir = '../data/two_years_each/train_val_consistent'

df_train_X = pd.read_excel(os.path.join(in_dir, 'train_X.xlsx'), header=0, index_col=0)
df_train_Y = pd.read_excel(os.path.join(in_dir, 'train_Y.xlsx'), header=0, index_col=0)

df_val_X = pd.read_excel(os.path.join(in_dir, 'val_X.xlsx'), header=0, index_col=0)
df_val_Y = pd.read_excel(os.path.join(in_dir, 'val_Y.xlsx'), header=0, index_col=0)

# %% [markdown]
# ### 目的変数の分布

# %%
sns.distplot(np.log(df_train_Y['SalesRyutsu'] + 0.00000001))
plt.plot()
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# []

# %%
def log(x):
    return np.log(x + 0.00000001)

#for c in ['Sales', 'Impressions', 'Clicks', 'Cost']:
for c in ['SalesRyutsu']:
    df_train_Y['SalesRyutsu_log'] = df_train_Y['SalesRyutsu'].apply(log)
    df_val_Y['SalesRyutsu_log'] = df_val_Y['SalesRyutsu'].apply(log)

# %% [markdown]
# ### データ構造転換

# %%
d_train_sales = xgb.DMatrix(df_train_X, label=df_train_Y['SalesRyutsu_log'])
d_val_sales = xgb.DMatrix(df_val_X, label=df_val_Y['SalesRyutsu_log'])

d_val = xgb.DMatrix(df_val_X)
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %% [markdown]
# ### パラメータのベイズ最適化

# %%
def score(params):
    print("Training with params: ")
    print(params)

    evals = [(d_train_sales, 'train'), (d_val_sales, 'eval')]
    evals_result = {}

    model = xgb.train(params, 
              d_train_sales, 
              num_boost_round=100, 
              evals=evals,
              early_stopping_rounds=20,
              evals_result=evals_result)
    
    d_pred = np.exp(model.predict(d_val))
    loss = mean_squared_error(d_pred, df_val_Y['SalesRyutsu'].values)
    print(f'loss: {loss}')
    return {'loss': loss, 'status': STATUS_OK}

def optimize(random_state=71):
    
    space = {
        'n_estimators': hp.quniform('n_estimators', 100, 1000, 1),
        'learning_rate': hp.quniform('eta', 0.025, 0.5, 0.025),
        'max_depth':  hp.choice('max_depth', np.arange(3, 10, dtype=int)),
        'min_child_weight': hp.loguniform('min_child_weight', np.log(0.1), np.log(10)),
        'subsample': hp.quniform('subsample', 0.6, 0.95, 0.05),
        'gamma': hp.loguniform('gamma', np.log(1e-8), np.log(1.0)),
        'colsample_bytree': hp.quniform('colsample_bytree', 0.6, 0.95, 0.05),
        'alpha': hp.loguniform('alpha', np.log(1e-8), np.log(1.0)),
        'lambda': hp.loguniform('lambda', np.log(1e-6), np.log(10.0)),
        'nthread': 4,
        'seed': random_state
    }
    best = fmin(score, space, 
                algo=tpe.suggest, 
                max_evals=250)
    return best
optimize()

# %% [markdown]
# ### xgboost モデルの作成

# %%
params = {
    'max_depth': 9,
    'learning_rate': 0.01,
    'n_estimators': 1000,
    'min_child_weight': 1,
    'gamma': 50,
    'colsample_bytree': 0.3,
    'subsample': 0.5,
    'random_state': 71,
    'objective': 'reg:squarederror',
    'n_jobs': -1,
    'reg_alpha': 0,
    'reg_lambda':1,
}

params = {'alpha': 0.0005210332926962755,
         'colsample_bytree': 0.6000000000000001,
         'eta': 0.15000000000000002,
         'gamma': 0.002707934511933379,
         'lambda': 1.619251503081484e-05,
         'max_depth': 1,
         'min_child_weight': 1.2380023493405914,
         'n_estimators': 106.0,
         'subsample': 0.8500000000000001}

evals = [(d_train_sales, 'train'), (d_val_sales, 'eval')]
evals_result = {}

model = xgb.train(params, 
          d_train_sales, 
          num_boost_round=1000, 
          evals=evals,
          early_stopping_rounds=20,
          evals_result=evals_result)
# Out:
# [0]	train-rmse:15.8129	eval-rmse:15.1733
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:13.664	eval-rmse:13.3221
# [2]	train-rmse:11.8537	eval-rmse:11.8056
# [3]	train-rmse:10.3337	eval-rmse:10.5569
# [4]	train-rmse:9.06818	eval-rmse:9.54948
# [5]	train-rmse:8.02182	eval-rmse:8.73541
# [6]	train-rmse:7.16009	eval-rmse:8.09442
# [7]	train-rmse:6.4673	eval-rmse:7.59989
# [8]	train-rmse:5.90519	eval-rmse:7.21251
# [9]	train-rmse:5.45688	eval-rmse:6.92035
# [10]	train-rmse:5.10313	eval-rmse:6.69559
# [11]	train-rmse:4.82716	eval-rmse:6.52476
# [12]	train-rmse:4.61555	eval-rmse:6.40046
# [13]	train-rmse:4.45066	eval-rmse:6.30525
# [14]	train-rmse:4.32464	eval-rmse:6.23678
# [15]	train-rmse:4.22901	eval-rmse:6.1851
# [16]	train-rmse:4.15669	eval-rmse:6.14258
# [17]	train-rmse:4.10234	eval-rmse:6.11451
# [18]	train-rmse:4.06106	eval-rmse:6.0929
# [19]	train-rmse:4.03079	eval-rmse:6.07601
# [20]	train-rmse:4.00696	eval-rmse:6.06072
# [21]	train-rmse:3.98847	eval-rmse:6.04885
# [22]	train-rmse:3.97461	eval-rmse:6.03823
# [23]	train-rmse:3.96337	eval-rmse:6.03338
# [24]	train-rmse:3.95433	eval-rmse:6.02963
# [25]	train-rmse:3.94738	eval-rmse:6.02283
# [26]	train-rmse:3.94207	eval-rmse:6.01981
# [27]	train-rmse:3.93695	eval-rmse:6.01798
# [28]	train-rmse:3.9333	eval-rmse:6.01284
# [29]	train-rmse:3.93042	eval-rmse:6.0113
# [30]	train-rmse:3.92801	eval-rmse:6.00712
# [31]	train-rmse:3.92536	eval-rmse:6.00613
# [32]	train-rmse:3.9241	eval-rmse:6.0041
# [33]	train-rmse:3.92223	eval-rmse:6.00318
# [34]	train-rmse:3.92074	eval-rmse:6.00026
# [35]	train-rmse:3.91994	eval-rmse:6.00002
# [36]	train-rmse:3.91922	eval-rmse:5.99903
# [37]	train-rmse:3.91856	eval-rmse:5.99904
# [38]	train-rmse:3.91737	eval-rmse:5.99683
# [39]	train-rmse:3.91693	eval-rmse:5.99583
# [40]	train-rmse:3.91649	eval-rmse:5.99584
# [41]	train-rmse:3.91604	eval-rmse:5.99529
# [42]	train-rmse:3.9156	eval-rmse:5.99369
# [43]	train-rmse:3.91532	eval-rmse:5.99369
# [44]	train-rmse:3.91499	eval-rmse:5.99318
# [45]	train-rmse:3.91438	eval-rmse:5.99318
# [46]	train-rmse:3.91416	eval-rmse:5.99287
# [47]	train-rmse:3.91389	eval-rmse:5.99276
# [48]	train-rmse:3.91364	eval-rmse:5.99146
# [49]	train-rmse:3.9135	eval-rmse:5.9908
# [50]	train-rmse:3.91339	eval-rmse:5.99085
# [51]	train-rmse:3.91318	eval-rmse:5.99103
# [52]	train-rmse:3.91275	eval-rmse:5.98981
# [53]	train-rmse:3.91262	eval-rmse:5.98939
# [54]	train-rmse:3.91231	eval-rmse:5.98922
# [55]	train-rmse:3.91222	eval-rmse:5.98809
# [56]	train-rmse:3.91197	eval-rmse:5.98783
# [57]	train-rmse:3.91188	eval-rmse:5.98755
# [58]	train-rmse:3.91168	eval-rmse:5.98754
# [59]	train-rmse:3.91158	eval-rmse:5.98775
# [60]	train-rmse:3.91156	eval-rmse:5.98769
# [61]	train-rmse:3.91127	eval-rmse:5.98788
# [62]	train-rmse:3.91117	eval-rmse:5.9879
# [63]	train-rmse:3.91106	eval-rmse:5.98791
# [64]	train-rmse:3.9109	eval-rmse:5.98688
# [65]	train-rmse:3.91071	eval-rmse:5.98651
# [66]	train-rmse:3.91087	eval-rmse:5.98649
# [67]	train-rmse:3.91053	eval-rmse:5.98648
# [68]	train-rmse:3.91066	eval-rmse:5.98611
# [69]	train-rmse:3.91048	eval-rmse:5.98603
# [70]	train-rmse:3.91018	eval-rmse:5.98584
# [71]	train-rmse:3.91009	eval-rmse:5.98604
# [72]	train-rmse:3.91005	eval-rmse:5.98596
# [73]	train-rmse:3.91005	eval-rmse:5.98565
# [74]	train-rmse:3.90994	eval-rmse:5.98567
# [75]	train-rmse:3.90975	eval-rmse:5.98562
# [76]	train-rmse:3.90966	eval-rmse:5.98572
# [77]	train-rmse:3.90971	eval-rmse:5.98578
# [78]	train-rmse:3.90961	eval-rmse:5.98596
# [79]	train-rmse:3.90955	eval-rmse:5.98579
# [80]	train-rmse:3.90947	eval-rmse:5.98584
# [81]	train-rmse:3.90934	eval-rmse:5.98561
# [82]	train-rmse:3.90912	eval-rmse:5.98536
# [83]	train-rmse:3.90911	eval-rmse:5.98518
# [84]	train-rmse:3.90903	eval-rmse:5.98523
# [85]	train-rmse:3.9089	eval-rmse:5.98496
# [86]	train-rmse:3.90882	eval-rmse:5.98493
# [87]	train-rmse:3.90872	eval-rmse:5.98493
# [88]	train-rmse:3.9086	eval-rmse:5.98499
# [89]	train-rmse:3.90856	eval-rmse:5.9849
# [90]	train-rmse:3.90852	eval-rmse:5.98469
# [91]	train-rmse:3.90848	eval-rmse:5.98467
# [92]	train-rmse:3.90834	eval-rmse:5.98437
# [93]	train-rmse:3.90826	eval-rmse:5.98438
# [94]	train-rmse:3.90821	eval-rmse:5.98421
# [95]	train-rmse:3.90807	eval-rmse:5.98344
# [96]	train-rmse:3.90795	eval-rmse:5.98352
# [97]	train-rmse:3.90793	eval-rmse:5.98344
# [98]	train-rmse:3.90782	eval-rmse:5.98354
# [99]	train-rmse:3.90774	eval-rmse:5.98356
# [100]	train-rmse:3.90766	eval-rmse:5.98328
# [101]	train-rmse:3.90754	eval-rmse:5.98323
# [102]	train-rmse:3.90747	eval-rmse:5.98321
# [103]	train-rmse:3.90737	eval-rmse:5.98349
# [104]	train-rmse:3.90735	eval-rmse:5.98352
# [105]	train-rmse:3.90727	eval-rmse:5.98358
# [106]	train-rmse:3.9072	eval-rmse:5.98343
# [107]	train-rmse:3.90717	eval-rmse:5.98265
# [108]	train-rmse:3.90706	eval-rmse:5.98283
# [109]	train-rmse:3.90699	eval-rmse:5.9834
# [110]	train-rmse:3.90691	eval-rmse:5.98336
# [111]	train-rmse:3.90686	eval-rmse:5.98344
# [112]	train-rmse:3.90688	eval-rmse:5.98339
# [113]	train-rmse:3.90681	eval-rmse:5.9834
# [114]	train-rmse:3.90666	eval-rmse:5.98322
# [115]	train-rmse:3.90652	eval-rmse:5.98291
# [116]	train-rmse:3.90646	eval-rmse:5.98278
# [117]	train-rmse:3.90643	eval-rmse:5.98288
# [118]	train-rmse:3.9064	eval-rmse:5.98276
# [119]	train-rmse:3.90635	eval-rmse:5.98273
# [120]	train-rmse:3.90629	eval-rmse:5.9827
# [121]	train-rmse:3.90626	eval-rmse:5.98269
# [122]	train-rmse:3.90623	eval-rmse:5.98278
# [123]	train-rmse:3.90619	eval-rmse:5.98276
# [124]	train-rmse:3.90608	eval-rmse:5.98202
# [125]	train-rmse:3.90609	eval-rmse:5.98201
# [126]	train-rmse:3.906	eval-rmse:5.98205
# [127]	train-rmse:3.90586	eval-rmse:5.98221
# [128]	train-rmse:3.9058	eval-rmse:5.98221
# [129]	train-rmse:3.90575	eval-rmse:5.98226
# [130]	train-rmse:3.90564	eval-rmse:5.98198
# [131]	train-rmse:3.90558	eval-rmse:5.9819
# [132]	train-rmse:3.90555	eval-rmse:5.98195
# [133]	train-rmse:3.90551	eval-rmse:5.98196
# [134]	train-rmse:3.90543	eval-rmse:5.98229
# [135]	train-rmse:3.90539	eval-rmse:5.98215
# [136]	train-rmse:3.9053	eval-rmse:5.98189
# [137]	train-rmse:3.90519	eval-rmse:5.98165
# [138]	train-rmse:3.90517	eval-rmse:5.98184
# [139]	train-rmse:3.90515	eval-rmse:5.98157
# [140]	train-rmse:3.90512	eval-rmse:5.9818
# [141]	train-rmse:3.90499	eval-rmse:5.98167
# [142]	train-rmse:3.90501	eval-rmse:5.9817
# [143]	train-rmse:3.90484	eval-rmse:5.98163
# [144]	train-rmse:3.90484	eval-rmse:5.98146
# [145]	train-rmse:3.90476	eval-rmse:5.98076
# [146]	train-rmse:3.90469	eval-rmse:5.98093
# [147]	train-rmse:3.90466	eval-rmse:5.9808
# [148]	train-rmse:3.90462	eval-rmse:5.98077
# [149]	train-rmse:3.90456	eval-rmse:5.98079
# [150]	train-rmse:3.90449	eval-rmse:5.98095
# [151]	train-rmse:3.90444	eval-rmse:5.98079
# [152]	train-rmse:3.90442	eval-rmse:5.98098
# [153]	train-rmse:3.90434	eval-rmse:5.98134
# [154]	train-rmse:3.90422	eval-rmse:5.98065
# [155]	train-rmse:3.90418	eval-rmse:5.97999
# [156]	train-rmse:3.90414	eval-rmse:5.98025
# [157]	train-rmse:3.9041	eval-rmse:5.98
# [158]	train-rmse:3.90407	eval-rmse:5.97993
# [159]	train-rmse:3.90396	eval-rmse:5.98002
# [160]	train-rmse:3.90399	eval-rmse:5.97995
# [161]	train-rmse:3.90394	eval-rmse:5.97978
# [162]	train-rmse:3.90385	eval-rmse:5.97964
# [163]	train-rmse:3.90379	eval-rmse:5.9794
# [164]	train-rmse:3.90369	eval-rmse:5.97951
# [165]	train-rmse:3.90364	eval-rmse:5.9795
# [166]	train-rmse:3.90358	eval-rmse:5.97948
# [167]	train-rmse:3.90351	eval-rmse:5.97942
# [168]	train-rmse:3.90347	eval-rmse:5.97949
# [169]	train-rmse:3.90343	eval-rmse:5.97952
# [170]	train-rmse:3.90337	eval-rmse:5.97967
# [171]	train-rmse:3.90335	eval-rmse:5.97941
# [172]	train-rmse:3.90332	eval-rmse:5.97948
# [173]	train-rmse:3.90327	eval-rmse:5.97942
# [174]	train-rmse:3.90333	eval-rmse:5.97917
# [175]	train-rmse:3.90316	eval-rmse:5.97921
# [176]	train-rmse:3.90314	eval-rmse:5.97932
# [177]	train-rmse:3.90304	eval-rmse:5.97907
# [178]	train-rmse:3.90299	eval-rmse:5.97905
# [179]	train-rmse:3.90297	eval-rmse:5.97898
# [180]	train-rmse:3.90293	eval-rmse:5.97897
# [181]	train-rmse:3.9029	eval-rmse:5.97905
# [182]	train-rmse:3.90288	eval-rmse:5.97914
# [183]	train-rmse:3.90281	eval-rmse:5.9792
# [184]	train-rmse:3.9027	eval-rmse:5.97857
# [185]	train-rmse:3.90265	eval-rmse:5.97843
# [186]	train-rmse:3.9026	eval-rmse:5.97842
# [187]	train-rmse:3.90254	eval-rmse:5.97847
# [188]	train-rmse:3.90248	eval-rmse:5.97823
# [189]	train-rmse:3.90242	eval-rmse:5.97812
# [190]	train-rmse:3.9024	eval-rmse:5.97802
# [191]	train-rmse:3.90238	eval-rmse:5.97797
# [192]	train-rmse:3.90238	eval-rmse:5.97804
# [193]	train-rmse:3.90235	eval-rmse:5.9781
# [194]	train-rmse:3.90231	eval-rmse:5.9781
# [195]	train-rmse:3.90226	eval-rmse:5.97809
# [196]	train-rmse:3.90222	eval-rmse:5.97816
# [197]	train-rmse:3.90216	eval-rmse:5.9781
# [198]	train-rmse:3.90212	eval-rmse:5.97801
# [199]	train-rmse:3.90203	eval-rmse:5.97812
# [200]	train-rmse:3.90202	eval-rmse:5.97825
# [201]	train-rmse:3.90192	eval-rmse:5.97811
# [202]	train-rmse:3.90192	eval-rmse:5.97806
# [203]	train-rmse:3.90179	eval-rmse:5.97816
# [204]	train-rmse:3.90179	eval-rmse:5.97817
# [205]	train-rmse:3.90172	eval-rmse:5.97812
# [206]	train-rmse:3.90166	eval-rmse:5.97856
# [207]	train-rmse:3.90163	eval-rmse:5.9783
# [208]	train-rmse:3.90159	eval-rmse:5.97832
# [209]	train-rmse:3.90155	eval-rmse:5.97831
# [210]	train-rmse:3.90148	eval-rmse:5.97823
# [211]	train-rmse:3.90143	eval-rmse:5.97809
# Stopping. Best iteration:
# [191]	train-rmse:3.90238	eval-rmse:5.97797

# %%
train_metric = evals_result['train']['rmse']
plt.plot(train_metric, label='train rmse')
eval_metric = evals_result['eval']['rmse']
plt.plot(eval_metric, label='eval rmse')
plt.grid()
plt.legend()
plt.xlabel('rounds')
plt.ylabel('rmse')
plt.show()

# %%
d_pred_log = model.predict(d_val)
d_pred = np.exp(d_pred_log)

#plt.plot(d_pred)
plt.figure(figsize=(15,5))
plt.plot(df_val_Y['SalesRyutsu'].values, label='real')
plt.plot(d_pred, label='pred')
plt.legend()
plt.grid()
plt.show()

# %%
_, ax = plt.subplots(figsize=(15,30))
xgb.plot_importance(model, ax=ax, importance_type='gain')
plt.show()

# %%
m = model.get_score(importance_type='gain')
sorted(m, key=lambda x: m[x], reverse=True)
# Out:
# ['SalesRyutsu_3',
#  'SalesRyutsu_5',
#  'SalesRyutsu_4',
#  'SalesRyutsu_6',
#  'UnitsRyutsu_1',
#  'SalesRyutsu_0',
#  'UnitsRyutsu_5',
#  'Cost_0',
#  'UnitsRyutsu_6',
#  'Audience_5',
#  'SalesRyutsu_2',
#  'UnitsRyutsu_4',
#  'AdvertiserId',
#  'Audience_6',
#  'UnitsRyutsu_2',
#  'UnitsKodateKen_5',
#  'Clicks_1',
#  'SalesKodateBkn_2',
#  'Audience_4',
#  'CpcBid_6',
#  'SalesSck_5',
#  'Cost_1',
#  'Cost_2',
#  'Cost_5',
#  'SalesRyutsu_1',
#  'UnitsMansionBkn_6',
#  'Clicks_2',
#  'Audience_1',
#  'Clicks_4',
#  'CpcBid_5',
#  'Cost_4',
#  'SalesMansionBkn_6',
#  'Cost_6',
#  'SalesMansionBkn_2',
#  'Audience_2',
#  'SalesRent_4',
#  'Clicks_6',
#  'CpcBid_4',
#  'SalesRent_5',
#  'SalesRent_2',
#  'CpcBid_2',
#  'UnitsMansionBkn_5',
#  'SalesRent_6',
#  'Cost_3',
#  'UnitsRent_5',
#  'Audience_3',
#  'SalesRent_3',
#  'Clicks_5',
#  'SalesRent_1',
#  'SalesRent_0',
#  'SalesKodateKen_1',
#  'Reach_2',
#  'UnitsRyutsu_3',
#  'Impressions_5',
#  'SalesMansionBkn_3',
#  'CpcBid_3',
#  'Reach_4',
#  'Clicks_0',
#  'UnitsRyutsu_0',
#  'SalesSck_4',
#  'UnitsRent_3',
#  'SalesMansionBkn_4',
#  'Impressions_6',
#  'CpcBid_1',
#  'Impressions_1',
#  'UnitsRent_4',
#  'SalesKodateBkn_4',
#  'CampaignId',
#  'Reach_3',
#  'Impressions_2',
#  'Impressions_3',
#  'Reach_5',
#  'SalesKodateBkn_3',
#  'UnitsMansionBkn_4',
#  'SalesKodateKen_5',
#  'Impressions_4',
#  'UnitsMansionBkn_2',
#  'OverallCompetitionWin_6',
#  'OverallCompetitionWin_5',
#  'OverallCompetitionWin_3',
#  'Reach_1',
#  'Clicks_3',
#  'UnitsRent_2',
#  'UnitsSck_5',
#  'OverallCompetitionWin_4',
#  'OverallCompetitionWin_2',
#  'Reach_6',
#  'UnitsRent_6',
#  'SalesKodateBkn_1',
#  'UnitsMansionBkn_1',
#  'Reach_0',
#  'OverallCompetitionWin_1',
#  'SalesMansionBkn_1',
#  'SalesMansionBkn_5',
#  'UnitsKodateBkn_3',
#  'UnitsKodateBkn_5',
#  'UnitsRent_1',
#  'UnitsKodateBkn_6',
#  'SalesSck_1',
#  'SalesSck_3',
#  'UnitsKodateBkn_2',
#  'SalesMansionBkn_0',
#  'SalesSck_2',
#  'Impressions_0',
#  'SalesKodateBkn_6',
#  'UnitsKodateKen_6',
#  'SalesSck_6',
#  'UnitsKodateBkn_1',
#  'UnitsRent_0',
#  'SalesKodateBkn_0',
#  'UnitsMansionBkn_3',
#  'UnitsSck_3',
#  'UnitsMansionBkn_0',
#  'UnitsKodateKen_4',
#  'UnitsKodateBkn_0',
#  'UnitsKodateBkn_4',
#  'SalesKodateBkn_5',
#  'UnitsKodateKen_2',
#  'UnitsSck_2',
#  'CategoryId',
#  'Audience_0',
#  'UnitsSck_6',
#  'UnitsSck_4',
#  'UnitsSck_1',
#  'CpcBid_0',
#  'UnitsKodateKen_3',
#  'UnitsKodateKen_0',
#  'UnitsSck_0',
#  'SalesKodateKen_4',
#  'UnitsMansionKen_1',
#  'UnitsKodateKen_1',
#  'SalesKodateKen_3',
#  'SalesSck_0',
#  'OverallCompetitionWin_0',
#  'UnitsMansionKen_6',
#  'SalesKodateKen_2',
#  'UnitsMansionKen_4',
#  'SalesKodateKen_6',
#  'SalesKodateKen_0',
#  'MarketId',
#  'UnitsMansionKen_2',
#  'UnitsMansionKen_5',
#  'UnitsMansionKen_3',
#  'UnitsMansionKen_0']
