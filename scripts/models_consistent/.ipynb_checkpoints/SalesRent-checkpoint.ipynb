# %%
import os
import numpy as np
import pandas as pd

import xgboost as xgb
from sklearn.multioutput import MultiOutputRegressor

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### データ読込

# %%
in_dir = '../data/two_years_each/train_val_consistent'

df_train_X = pd.read_excel(os.path.join(in_dir, 'train_X.xlsx'), header=0, index_col=0)
df_train_Y = pd.read_excel(os.path.join(in_dir, 'train_Y.xlsx'), header=0, index_col=0)

df_val_X = pd.read_excel(os.path.join(in_dir, 'val_X.xlsx'), header=0, index_col=0)
df_val_Y = pd.read_excel(os.path.join(in_dir, 'val_Y.xlsx'), header=0, index_col=0)

# %% [markdown]
# ### 目的変数の分布

# %%
sns.distplot(np.log(df_train_Y['SalesRent'] + 0.00000001))
plt.plot()
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# []

# %%
sns.distplot(df_train_Y['SalesRent'], label='train')
sns.distplot(df_val_Y['SalesRent'], label='val')
plt.legend()
plt.plot()
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# []

# %%
def log(x):
    return np.log(x + 0.00000001)

#for c in ['Sales', 'Impressions', 'Clicks', 'Cost']:
for c in ['SalesRent']:
    df_train_Y['SalesRent_log'] = df_train_Y['SalesRent'].apply(log)
    df_val_Y['SalesRent_log'] = df_val_Y['SalesRent'].apply(log)

# %% [markdown]
# ### データ構造転換

# %%
d_train_sales = xgb.DMatrix(df_train_X, label=df_train_Y['SalesRent_log'])
d_val_sales = xgb.DMatrix(df_val_X, label=df_val_Y['SalesRent_log'])

d_val = xgb.DMatrix(df_val_X)
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %% [markdown]
# ### xgboost モデルの作成

# %%
params = {
    'max_depth': 10,
    'learning_rate': 0.1,
    'n_estimators': 1500,
    'objective': 'reg:squarederror',
    'n_jobs': -1,
    'reg_alpha': 10,
    'reg_lambda':10,
}

evals = [(d_train_sales, 'train'), (d_val_sales, 'eval')]
evals_result = {}

model = xgb.train(params, 
          d_train_sales, 
          num_boost_round=100, 
          evals=evals,
          evals_result=evals_result)
# Out:
# [0]	train-rmse:15.8527	eval-rmse:15.3639
# [1]	train-rmse:14.3229	eval-rmse:13.9122
# [2]	train-rmse:12.9491	eval-rmse:12.6138
# [3]	train-rmse:11.7172	eval-rmse:11.4564
# [4]	train-rmse:10.6117	eval-rmse:10.4201
# [5]	train-rmse:9.62301	eval-rmse:9.50248
# [6]	train-rmse:8.73574	eval-rmse:8.69017
# [7]	train-rmse:7.94212	eval-rmse:7.9721
# [8]	train-rmse:7.23325	eval-rmse:7.34087
# [9]	train-rmse:6.60087	eval-rmse:6.78005
# [10]	train-rmse:6.03626	eval-rmse:6.29122
# [11]	train-rmse:5.53481	eval-rmse:5.86463
# [12]	train-rmse:5.08875	eval-rmse:5.49309
# [13]	train-rmse:4.69395	eval-rmse:5.17405
# [14]	train-rmse:4.34314	eval-rmse:4.89922
# [15]	train-rmse:4.03312	eval-rmse:4.66585
# [16]	train-rmse:3.75986	eval-rmse:4.46756
# [17]	train-rmse:3.52124	eval-rmse:4.30466
# [18]	train-rmse:3.30995	eval-rmse:4.16567
# [19]	train-rmse:3.12677	eval-rmse:4.04932
# [20]	train-rmse:2.96428	eval-rmse:3.95304
# [21]	train-rmse:2.82492	eval-rmse:3.87481
# [22]	train-rmse:2.70301	eval-rmse:3.80745
# [23]	train-rmse:2.59307	eval-rmse:3.75037
# [24]	train-rmse:2.5049	eval-rmse:3.70634
# [25]	train-rmse:2.42706	eval-rmse:3.67114
# [26]	train-rmse:2.36002	eval-rmse:3.63614
# [27]	train-rmse:2.30042	eval-rmse:3.60984
# [28]	train-rmse:2.2463	eval-rmse:3.59172
# [29]	train-rmse:2.2008	eval-rmse:3.57586
# [30]	train-rmse:2.16273	eval-rmse:3.56274
# [31]	train-rmse:2.12409	eval-rmse:3.55419
# [32]	train-rmse:2.09107	eval-rmse:3.54281
# [33]	train-rmse:2.06051	eval-rmse:3.53301
# [34]	train-rmse:2.03652	eval-rmse:3.5249
# [35]	train-rmse:2.01509	eval-rmse:3.51805
# [36]	train-rmse:1.99461	eval-rmse:3.51387
# [37]	train-rmse:1.96803	eval-rmse:3.50774
# [38]	train-rmse:1.95466	eval-rmse:3.5052
# [39]	train-rmse:1.93799	eval-rmse:3.49881
# [40]	train-rmse:1.92638	eval-rmse:3.49724
# [41]	train-rmse:1.9046	eval-rmse:3.49477
# [42]	train-rmse:1.8914	eval-rmse:3.49485
# [43]	train-rmse:1.87935	eval-rmse:3.49276
# [44]	train-rmse:1.87111	eval-rmse:3.49349
# [45]	train-rmse:1.8612	eval-rmse:3.49464
# [46]	train-rmse:1.8531	eval-rmse:3.49509
# [47]	train-rmse:1.84545	eval-rmse:3.49487
# [48]	train-rmse:1.83856	eval-rmse:3.49496
# [49]	train-rmse:1.82914	eval-rmse:3.49335
# [50]	train-rmse:1.8202	eval-rmse:3.49272
# [51]	train-rmse:1.80777	eval-rmse:3.49508
# [52]	train-rmse:1.79773	eval-rmse:3.49304
# [53]	train-rmse:1.78842	eval-rmse:3.49279
# [54]	train-rmse:1.7777	eval-rmse:3.49436
# [55]	train-rmse:1.76901	eval-rmse:3.49677
# [56]	train-rmse:1.76167	eval-rmse:3.49632
# [57]	train-rmse:1.75381	eval-rmse:3.49576
# [58]	train-rmse:1.74847	eval-rmse:3.49525
# [59]	train-rmse:1.74444	eval-rmse:3.49428
# [60]	train-rmse:1.74131	eval-rmse:3.49404
# [61]	train-rmse:1.73259	eval-rmse:3.49304
# [62]	train-rmse:1.72568	eval-rmse:3.49404
# [63]	train-rmse:1.72295	eval-rmse:3.4933
# [64]	train-rmse:1.71624	eval-rmse:3.49439
# [65]	train-rmse:1.7072	eval-rmse:3.49429
# [66]	train-rmse:1.70356	eval-rmse:3.49474
# [67]	train-rmse:1.69917	eval-rmse:3.49224
# [68]	train-rmse:1.69587	eval-rmse:3.49265
# [69]	train-rmse:1.68817	eval-rmse:3.49379
# [70]	train-rmse:1.68626	eval-rmse:3.49374
# [71]	train-rmse:1.68041	eval-rmse:3.49363
# [72]	train-rmse:1.67573	eval-rmse:3.49476
# [73]	train-rmse:1.66782	eval-rmse:3.4937
# [74]	train-rmse:1.65676	eval-rmse:3.49444
# [75]	train-rmse:1.6455	eval-rmse:3.49538
# [76]	train-rmse:1.63818	eval-rmse:3.49545
# [77]	train-rmse:1.63056	eval-rmse:3.49599
# [78]	train-rmse:1.62339	eval-rmse:3.49673
# [79]	train-rmse:1.61554	eval-rmse:3.4967
# [80]	train-rmse:1.60833	eval-rmse:3.49704
# [81]	train-rmse:1.6017	eval-rmse:3.49673
# [82]	train-rmse:1.59487	eval-rmse:3.49619
# [83]	train-rmse:1.58858	eval-rmse:3.49611
# [84]	train-rmse:1.58359	eval-rmse:3.49602
# [85]	train-rmse:1.57571	eval-rmse:3.49719
# [86]	train-rmse:1.57068	eval-rmse:3.49743
# [87]	train-rmse:1.56121	eval-rmse:3.49614
# [88]	train-rmse:1.55565	eval-rmse:3.49776
# [89]	train-rmse:1.5491	eval-rmse:3.49922
# [90]	train-rmse:1.54111	eval-rmse:3.49815
# [91]	train-rmse:1.53504	eval-rmse:3.49707
# [92]	train-rmse:1.53	eval-rmse:3.49825
# [93]	train-rmse:1.52266	eval-rmse:3.49889
# [94]	train-rmse:1.51535	eval-rmse:3.49888
# [95]	train-rmse:1.51117	eval-rmse:3.49826
# [96]	train-rmse:1.50562	eval-rmse:3.49908
# [97]	train-rmse:1.50155	eval-rmse:3.49864
# [98]	train-rmse:1.49199	eval-rmse:3.4993
# [99]	train-rmse:1.48048	eval-rmse:3.49787

# %%
train_metric = evals_result['train']['rmse']
plt.plot(train_metric, label='train rmse')
eval_metric = evals_result['eval']['rmse']
plt.plot(eval_metric, label='eval rmse')
plt.grid()
plt.legend()
plt.xlabel('rounds')
plt.ylabel('rmse')
plt.show()

# %%
d_pred_log = model.predict(d_val)
d_pred = np.exp(d_pred_log)

#plt.plot(d_pred)
plt.figure(figsize=(15,5))
plt.plot(df_val_Y['SalesRent'].values, label='real')
plt.plot(d_pred, label='pred')
plt.legend()
plt.grid()
plt.show()

# %%
_, ax = plt.subplots(figsize=(15,30))
xgb.plot_importance(model, ax=ax, importance_type='gain')
plt.show()

# %%
m = model.get_score(importance_type='gain')
sorted(m, key=lambda x: m[x], reverse=True)
# Out:
# ['SalesRent_0',
#  'SalesRent_3',
#  'SalesRent_1',
#  'SalesRent_2',
#  'SalesRent_4',
#  'MarketId',
#  'SalesRent_6',
#  'SalesKodateKen_6',
#  'SalesMansionBkn_4',
#  'SalesSck_0',
#  'Clicks_0',
#  'CpcBid_1',
#  'SalesSck_6',
#  'SalesKodateKen_4',
#  'SalesRent_5',
#  'Clicks_3',
#  'SalesMansionBkn_0',
#  'SalesSck_2',
#  'CpcBid_6',
#  'SalesKodateBkn_1',
#  'SalesKodateKen_0',
#  'UnitsRent_4',
#  'Clicks_6',
#  'SalesMansionBkn_2',
#  'Audience_6',
#  'SalesRyutsu_0',
#  'SalesMansionBkn_1',
#  'SalesRyutsu_6',
#  'UnitsKodateKen_2',
#  'SalesSck_1',
#  'SalesKodateBkn_0',
#  'SalesRyutsu_2',
#  'Audience_4',
#  'Audience_3',
#  'SalesKodateBkn_4',
#  'Impressions_1',
#  'SalesMansionBkn_5',
#  'SalesKodateKen_5',
#  'UnitsKodateKen_6',
#  'Clicks_2',
#  'SalesRyutsu_4',
#  'Reach_3',
#  'SalesRyutsu_1',
#  'SalesSck_4',
#  'Clicks_1',
#  'Cost_1',
#  'OverallCompetitionWin_3',
#  'OverallCompetitionWin_4',
#  'Audience_2',
#  'OverallCompetitionWin_5',
#  'Cost_3',
#  'Audience_0',
#  'SalesRyutsu_3',
#  'Impressions_6',
#  'Cost_4',
#  'Impressions_3',
#  'Reach_6',
#  'Clicks_5',
#  'Audience_5',
#  'UnitsMansionKen_3',
#  'Cost_0',
#  'Reach_4',
#  'CpcBid_4',
#  'CpcBid_5',
#  'Impressions_4',
#  'Reach_5',
#  'Cost_6',
#  'UnitsMansionKen_2',
#  'Reach_2',
#  'Impressions_5',
#  'SalesKodateBkn_2',
#  'UnitsSck_3',
#  'UnitsRent_1',
#  'Clicks_4',
#  'OverallCompetitionWin_6',
#  'UnitsSck_4',
#  'OverallCompetitionWin_2',
#  'Reach_1',
#  'UnitsKodateKen_5',
#  'SalesKodateBkn_5',
#  'UnitsRent_6',
#  'Audience_1',
#  'Cost_5',
#  'CpcBid_2',
#  'Cost_2',
#  'UnitsRyutsu_6',
#  'SalesRyutsu_5',
#  'SalesKodateBkn_3',
#  'UnitsSck_0',
#  'OverallCompetitionWin_1',
#  'UnitsKodateBkn_4',
#  'SalesSck_3',
#  'UnitsRyutsu_4',
#  'Impressions_0',
#  'UnitsRent_0',
#  'UnitsKodateKen_1',
#  'SalesSck_5',
#  'UnitsRent_2',
#  'SalesMansionBkn_6',
#  'UnitsRent_5',
#  'SalesKodateBkn_6',
#  'Impressions_2',
#  'UnitsRyutsu_2',
#  'CpcBid_3',
#  'UnitsKodateBkn_5',
#  'UnitsRyutsu_1',
#  'UnitsRent_3',
#  'UnitsRyutsu_5',
#  'UnitsRyutsu_3',
#  'UnitsKodateKen_3',
#  'CategoryId',
#  'SalesKodateKen_3',
#  'UnitsSck_6',
#  'SalesMansionBkn_3',
#  'UnitsKodateBkn_1',
#  'Reach_0',
#  'UnitsKodateBkn_2',
#  'UnitsSck_2',
#  'UnitsMansionBkn_3',
#  'UnitsSck_5',
#  'UnitsKodateBkn_6',
#  'UnitsSck_1',
#  'UnitsMansionBkn_5',
#  'UnitsMansionBkn_1',
#  'UnitsKodateKen_4',
#  'UnitsMansionBkn_4',
#  'UnitsMansionKen_6',
#  'UnitsMansionBkn_6',
#  'UnitsKodateBkn_0',
#  'UnitsRyutsu_0',
#  'UnitsMansionBkn_0',
#  'UnitsKodateKen_0',
#  'UnitsKodateBkn_3',
#  'OverallCompetitionWin_0',
#  'UnitsMansionBkn_2',
#  'CpcBid_0',
#  'UnitsMansionKen_0',
#  'UnitsMansionKen_4',
#  'AdvertiserId',
#  'UnitsMansionKen_5',
#  'CampaignId',
#  'SalesKodateKen_1',
#  'UnitsMansionKen_1',
#  'SalesMansionKen_0',
#  'SalesMansionKen_6',
#  'SalesMansionKen_4',
#  'SalesKodateKen_2',
#  'SalesMansionKen_3']
