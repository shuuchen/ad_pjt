# %%
import os
import numpy as np
import pandas as pd

import xgboost as xgb
from sklearn.multioutput import MultiOutputRegressor

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### データ読込

# %%
in_dir = '../data/two_years_each/train_val_consistent'

df_train_X = pd.read_excel(os.path.join(in_dir, 'train_X.xlsx'), header=0, index_col=0)
df_train_Y = pd.read_excel(os.path.join(in_dir, 'train_Y.xlsx'), header=0, index_col=0)

df_val_X = pd.read_excel(os.path.join(in_dir, 'val_X.xlsx'), header=0, index_col=0)
df_val_Y = pd.read_excel(os.path.join(in_dir, 'val_Y.xlsx'), header=0, index_col=0)

# %% [markdown]
# ### 目的変数の分布

# %%
sns.distplot(np.log(df_train_Y['SalesMansionKen'] + 0.00000001))
plt.plot()
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# []

# %%
sns.distplot(df_train_Y['SalesMansionKen'], label='train')
sns.distplot(df_val_Y['SalesMansionKen'], label='val')
plt.legend()
plt.plot()
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# []

# %%
def log(x):
    return np.log(x + 0.00000001)

#for c in ['Sales', 'Impressions', 'Clicks', 'Cost']:
for c in ['SalesMansionKen']:
    df_train_Y['SalesMansionKen_log'] = df_train_Y['SalesMansionKen'].apply(log)
    df_val_Y['SalesMansionKen_log'] = df_val_Y['SalesMansionKen'].apply(log)

# %% [markdown]
# ### データ構造転換

# %%
d_train_sales = xgb.DMatrix(df_train_X, label=df_train_Y['SalesMansionKen_log'])
d_val_sales = xgb.DMatrix(df_val_X, label=df_val_Y['SalesMansionKen_log'])

d_val = xgb.DMatrix(df_val_X)
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %% [markdown]
# ### xgboost モデルの作成

# %%
params = {
    'max_depth': 10,
    'learning_rate': 0.1,
    'n_estimators': 1500,
    'objective': 'reg:squarederror',
    'n_jobs': -1,
    'reg_alpha': 10,
    'reg_lambda':10,
}

evals = [(d_train_sales, 'train'), (d_val_sales, 'eval')]
evals_result = {}

model = xgb.train(params, 
          d_train_sales, 
          num_boost_round=100, 
          evals=evals,
          evals_result=evals_result)
# Out:
# [0]	train-rmse:17.0272	eval-rmse:16.9966
# [1]	train-rmse:15.3279	eval-rmse:15.3139
# [2]	train-rmse:13.796	eval-rmse:13.8032
# [3]	train-rmse:12.4199	eval-rmse:12.4474
# [4]	train-rmse:11.179	eval-rmse:11.2319
# [5]	train-rmse:10.0646	eval-rmse:10.1429
# [6]	train-rmse:9.06116	eval-rmse:9.16917
# [7]	train-rmse:8.15853	eval-rmse:8.2977
# [8]	train-rmse:7.34646	eval-rmse:7.51974
# [9]	train-rmse:6.61658	eval-rmse:6.82441
# [10]	train-rmse:5.95922	eval-rmse:6.20734
# [11]	train-rmse:5.3679	eval-rmse:5.65972
# [12]	train-rmse:4.83695	eval-rmse:5.17497
# [13]	train-rmse:4.35867	eval-rmse:4.74689
# [14]	train-rmse:3.92929	eval-rmse:4.37051
# [15]	train-rmse:3.54388	eval-rmse:4.0425
# [16]	train-rmse:3.19729	eval-rmse:3.75553
# [17]	train-rmse:2.88598	eval-rmse:3.50739
# [18]	train-rmse:2.60675	eval-rmse:3.29432
# [19]	train-rmse:2.35645	eval-rmse:3.11129
# [20]	train-rmse:2.13198	eval-rmse:2.95591
# [21]	train-rmse:1.93062	eval-rmse:2.82486
# [22]	train-rmse:1.75099	eval-rmse:2.71393
# [23]	train-rmse:1.58922	eval-rmse:2.62126
# [24]	train-rmse:1.44484	eval-rmse:2.54393
# [25]	train-rmse:1.3159	eval-rmse:2.4809
# [26]	train-rmse:1.20238	eval-rmse:2.42977
# [27]	train-rmse:1.10069	eval-rmse:2.3877
# [28]	train-rmse:1.01187	eval-rmse:2.35344
# [29]	train-rmse:0.932854	eval-rmse:2.32552
# [30]	train-rmse:0.863671	eval-rmse:2.30352
# [31]	train-rmse:0.801187	eval-rmse:2.2858
# [32]	train-rmse:0.746543	eval-rmse:2.2717
# [33]	train-rmse:0.698675	eval-rmse:2.25994
# [34]	train-rmse:0.656686	eval-rmse:2.25101
# [35]	train-rmse:0.620162	eval-rmse:2.24362
# [36]	train-rmse:0.588494	eval-rmse:2.23837
# [37]	train-rmse:0.56121	eval-rmse:2.23405
# [38]	train-rmse:0.53755	eval-rmse:2.23056
# [39]	train-rmse:0.517046	eval-rmse:2.22775
# [40]	train-rmse:0.499521	eval-rmse:2.22501
# [41]	train-rmse:0.484136	eval-rmse:2.22371
# [42]	train-rmse:0.470875	eval-rmse:2.22281
# [43]	train-rmse:0.459135	eval-rmse:2.22217
# [44]	train-rmse:0.448972	eval-rmse:2.22172
# [45]	train-rmse:0.440291	eval-rmse:2.2216
# [46]	train-rmse:0.43242	eval-rmse:2.22104
# [47]	train-rmse:0.425513	eval-rmse:2.22105
# [48]	train-rmse:0.419112	eval-rmse:2.22089
# [49]	train-rmse:0.413387	eval-rmse:2.22117
# [50]	train-rmse:0.40725	eval-rmse:2.2203
# [51]	train-rmse:0.401641	eval-rmse:2.21955
# [52]	train-rmse:0.396366	eval-rmse:2.21959
# [53]	train-rmse:0.391156	eval-rmse:2.21962
# [54]	train-rmse:0.386487	eval-rmse:2.21953
# [55]	train-rmse:0.382036	eval-rmse:2.21953
# [56]	train-rmse:0.377654	eval-rmse:2.2191
# [57]	train-rmse:0.37364	eval-rmse:2.21943
# [58]	train-rmse:0.369742	eval-rmse:2.21905
# [59]	train-rmse:0.365727	eval-rmse:2.21881
# [60]	train-rmse:0.361732	eval-rmse:2.21925
# [61]	train-rmse:0.358087	eval-rmse:2.21919
# [62]	train-rmse:0.354072	eval-rmse:2.2192
# [63]	train-rmse:0.350529	eval-rmse:2.21919
# [64]	train-rmse:0.346937	eval-rmse:2.21928
# [65]	train-rmse:0.34325	eval-rmse:2.21931
# [66]	train-rmse:0.339912	eval-rmse:2.21955
# [67]	train-rmse:0.336725	eval-rmse:2.21904
# [68]	train-rmse:0.33357	eval-rmse:2.21882
# [69]	train-rmse:0.330499	eval-rmse:2.21857
# [70]	train-rmse:0.327366	eval-rmse:2.21865
# [71]	train-rmse:0.32448	eval-rmse:2.21806
# [72]	train-rmse:0.321807	eval-rmse:2.21785
# [73]	train-rmse:0.318961	eval-rmse:2.21762
# [74]	train-rmse:0.316361	eval-rmse:2.21764
# [75]	train-rmse:0.313652	eval-rmse:2.21776
# [76]	train-rmse:0.310596	eval-rmse:2.21785
# [77]	train-rmse:0.307781	eval-rmse:2.2179
# [78]	train-rmse:0.3045	eval-rmse:2.21803
# [79]	train-rmse:0.301517	eval-rmse:2.21796
# [80]	train-rmse:0.298948	eval-rmse:2.21809
# [81]	train-rmse:0.296986	eval-rmse:2.21834
# [82]	train-rmse:0.294196	eval-rmse:2.21789
# [83]	train-rmse:0.2914	eval-rmse:2.21805
# [84]	train-rmse:0.289177	eval-rmse:2.21814
# [85]	train-rmse:0.286049	eval-rmse:2.21818
# [86]	train-rmse:0.283757	eval-rmse:2.2181
# [87]	train-rmse:0.280795	eval-rmse:2.21706
# [88]	train-rmse:0.277952	eval-rmse:2.21727
# [89]	train-rmse:0.275463	eval-rmse:2.21678
# [90]	train-rmse:0.273422	eval-rmse:2.21576
# [91]	train-rmse:0.271663	eval-rmse:2.21488
# [92]	train-rmse:0.26936	eval-rmse:2.215
# [93]	train-rmse:0.266617	eval-rmse:2.21489
# [94]	train-rmse:0.264602	eval-rmse:2.21501
# [95]	train-rmse:0.262646	eval-rmse:2.21475
# [96]	train-rmse:0.260241	eval-rmse:2.21506
# [97]	train-rmse:0.257942	eval-rmse:2.21515
# [98]	train-rmse:0.256015	eval-rmse:2.2151
# [99]	train-rmse:0.253945	eval-rmse:2.21513

# %%
train_metric = evals_result['train']['rmse']
plt.plot(train_metric, label='train rmse')
eval_metric = evals_result['eval']['rmse']
plt.plot(eval_metric, label='eval rmse')
plt.grid()
plt.legend()
plt.xlabel('rounds')
plt.ylabel('rmse')
plt.show()

# %%
d_pred_log = model.predict(d_val)
d_pred = np.exp(d_pred_log)

#plt.plot(d_pred)
plt.figure(figsize=(15,5))
plt.plot(df_val_Y['SalesMansionKen'].values, label='real')
plt.plot(d_pred, label='pred')
plt.legend()
plt.grid()
plt.show()

# %%
_, ax = plt.subplots(figsize=(15,30))
xgb.plot_importance(model, ax=ax, importance_type='gain')
plt.show()

# %%
m = model.get_score(importance_type='gain')
sorted(m, key=lambda x: m[x], reverse=True)
# Out:
# ['SalesMansionKen_4',
#  'UnitsMansionKen_5',
#  'SalesMansionKen_2',
#  'Impressions_5',
#  'Reach_5',
#  'Cost_6',
#  'UnitsRent_3',
#  'Cost_0',
#  'CpcBid_6',
#  'SalesMansionKen_6',
#  'UnitsMansionKen_0',
#  'SalesMansionKen_0',
#  'Impressions_2',
#  'UnitsRent_1',
#  'Clicks_0',
#  'Clicks_6',
#  'Audience_1',
#  'OverallCompetitionWin_1',
#  'Cost_1',
#  'Audience_6',
#  'UnitsMansionBkn_2',
#  'UnitsSck_1',
#  'UnitsRyutsu_4',
#  'Clicks_1',
#  'UnitsMansionKen_2',
#  'OverallCompetitionWin_2',
#  'Reach_0',
#  'UnitsMansionKen_1',
#  'Impressions_1',
#  'SalesMansionBkn_1',
#  'Impressions_3',
#  'UnitsMansionBkn_6',
#  'UnitsMansionBkn_1',
#  'OverallCompetitionWin_0',
#  'UnitsRent_4',
#  'SalesMansionKen_5',
#  'UnitsRent_2',
#  'CpcBid_5',
#  'UnitsRent_0',
#  'Audience_2',
#  'SalesSck_6',
#  'SalesRent_0',
#  'Reach_2',
#  'UnitsRyutsu_5',
#  'Cost_5',
#  'UnitsSck_4',
#  'SalesKodateKen_5',
#  'Audience_0',
#  'SalesMansionBkn_4',
#  'UnitsSck_6',
#  'UnitsRyutsu_2',
#  'OverallCompetitionWin_5',
#  'SalesRent_4',
#  'SalesRyutsu_6',
#  'Audience_4',
#  'SalesMansionBkn_0',
#  'Reach_6',
#  'SalesMansionBkn_2',
#  'UnitsKodateBkn_2',
#  'SalesKodateKen_6',
#  'UnitsMansionBkn_5',
#  'UnitsMansionBkn_0',
#  'OverallCompetitionWin_6',
#  'Impressions_4',
#  'SalesRent_5',
#  'UnitsKodateKen_3',
#  'UnitsRent_5',
#  'SalesMansionKen_1',
#  'Reach_3',
#  'UnitsRyutsu_0',
#  'Impressions_0',
#  'UnitsRent_6',
#  'SalesRent_3',
#  'Clicks_3',
#  'SalesKodateBkn_4',
#  'Audience_3',
#  'CpcBid_3',
#  'Cost_3',
#  'Impressions_6',
#  'SalesMansionBkn_3',
#  'UnitsMansionBkn_4',
#  'SalesRyutsu_4',
#  'OverallCompetitionWin_3',
#  'UnitsRyutsu_1',
#  'UnitsRyutsu_3',
#  'SalesSck_4',
#  'CategoryId',
#  'CpcBid_0',
#  'SalesRent_1',
#  'OverallCompetitionWin_4',
#  'AdvertiserId',
#  'Clicks_5',
#  'UnitsMansionBkn_3',
#  'Reach_4',
#  'SalesMansionBkn_6',
#  'CampaignId',
#  'SalesRyutsu_3',
#  'SalesMansionKen_3',
#  'SalesRyutsu_5',
#  'UnitsRyutsu_6',
#  'Clicks_2',
#  'MarketId',
#  'Audience_5',
#  'CpcBid_4',
#  'SalesMansionBkn_5',
#  'Cost_4',
#  'SalesRyutsu_0',
#  'UnitsSck_0',
#  'SalesRyutsu_1',
#  'UnitsKodateBkn_0',
#  'CpcBid_1',
#  'UnitsKodateKen_2',
#  'Reach_1',
#  'CpcBid_2',
#  'Clicks_4',
#  'UnitsMansionKen_3',
#  'UnitsMansionKen_4',
#  'UnitsSck_5',
#  'Cost_2',
#  'UnitsMansionKen_6',
#  'UnitsKodateBkn_5',
#  'UnitsKodateBkn_3',
#  'SalesKodateBkn_5',
#  'UnitsKodateBkn_1',
#  'UnitsKodateKen_1',
#  'UnitsKodateKen_0',
#  'UnitsKodateKen_4',
#  'UnitsSck_2',
#  'SalesSck_1',
#  'UnitsKodateKen_6',
#  'SalesRent_2',
#  'UnitsKodateBkn_6',
#  'SalesKodateKen_4',
#  'SalesRyutsu_2',
#  'UnitsKodateBkn_4',
#  'SalesSck_2',
#  'UnitsSck_3',
#  'SalesKodateBkn_1',
#  'UnitsKodateKen_5',
#  'SalesKodateKen_1',
#  'SalesKodateBkn_6',
#  'SalesKodateBkn_0']
