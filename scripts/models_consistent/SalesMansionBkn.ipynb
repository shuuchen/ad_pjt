# %%
import os
import numpy as np
import pandas as pd

import xgboost as xgb
from sklearn.multioutput import MultiOutputRegressor

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### データ読込

# %%
in_dir = '../data/two_years_each/train_val_consistent'

df_train_X = pd.read_excel(os.path.join(in_dir, 'train_X.xlsx'), header=0, index_col=0)
df_train_Y = pd.read_excel(os.path.join(in_dir, 'train_Y.xlsx'), header=0, index_col=0)

df_val_X = pd.read_excel(os.path.join(in_dir, 'val_X.xlsx'), header=0, index_col=0)
df_val_Y = pd.read_excel(os.path.join(in_dir, 'val_Y.xlsx'), header=0, index_col=0)

# %% [markdown]
# ### 目的変数の分布

# %%
sns.distplot(np.log(df_train_Y['SalesMansionBkn'] + 0.00000001))
plt.plot()

sns.distplot(np.log(df_val_Y['SalesMansionBkn'] + 0.00000001))
plt.plot()
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# []

# %%
sns.distplot(df_train_Y['SalesMansionBkn'], label='train')
sns.distplot(df_val_Y['SalesMansionBkn'], label='val')
plt.legend()
plt.plot()
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# []

# %%
def log(x):
    return np.log(x + 0.00000001)

#for c in ['Sales', 'Impressions', 'Clicks', 'Cost']:
for c in ['SalesMansionBkn']:
    df_train_Y['SalesMansionBkn_log'] = df_train_Y['SalesMansionBkn'].apply(log)
    df_val_Y['SalesMansionBkn_log'] = df_val_Y['SalesMansionBkn'].apply(log)

# %% [markdown]
# ### データ構造転換

# %%
d_train_sales = xgb.DMatrix(df_train_X, label=df_train_Y['SalesMansionBkn_log'])
d_val_sales = xgb.DMatrix(df_val_X, label=df_val_Y['SalesMansionBkn_log'])

d_val = xgb.DMatrix(df_val_X)
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %% [markdown]
# ### xgboost モデルの作成

# %%
params = {
    'max_depth': 10,
    'learning_rate': 0.1,
    'n_estimators': 1500,
    'objective': 'reg:squarederror',
    'n_jobs': -1,
    'reg_alpha': 10,
    'reg_lambda':10,
}

evals = [(d_train_sales, 'train'), (d_val_sales, 'eval')]
evals_result = {}

model = xgb.train(params, 
          d_train_sales, 
          num_boost_round=100, 
          evals=evals,
          evals_result=evals_result)
# Out:
# [0]	train-rmse:16.8708	eval-rmse:16.7906
# [1]	train-rmse:15.2528	eval-rmse:15.2211
# [2]	train-rmse:13.8027	eval-rmse:13.821
# [3]	train-rmse:12.5017	eval-rmse:12.5775
# [4]	train-rmse:11.3382	eval-rmse:11.4786
# [5]	train-rmse:10.2929	eval-rmse:10.4967
# [6]	train-rmse:9.36437	eval-rmse:9.6493
# [7]	train-rmse:8.5316	eval-rmse:8.88415
# [8]	train-rmse:7.7876	eval-rmse:8.20955
# [9]	train-rmse:7.12717	eval-rmse:7.62523
# [10]	train-rmse:6.53997	eval-rmse:7.11308
# [11]	train-rmse:6.01931	eval-rmse:6.67213
# [12]	train-rmse:5.55715	eval-rmse:6.29135
# [13]	train-rmse:5.15114	eval-rmse:5.96363
# [14]	train-rmse:4.79218	eval-rmse:5.68252
# [15]	train-rmse:4.47598	eval-rmse:5.44686
# [16]	train-rmse:4.19567	eval-rmse:5.24862
# [17]	train-rmse:3.95485	eval-rmse:5.08198
# [18]	train-rmse:3.74474	eval-rmse:4.94506
# [19]	train-rmse:3.56462	eval-rmse:4.83649
# [20]	train-rmse:3.40492	eval-rmse:4.74106
# [21]	train-rmse:3.27362	eval-rmse:4.66265
# [22]	train-rmse:3.1566	eval-rmse:4.60152
# [23]	train-rmse:3.05409	eval-rmse:4.55072
# [24]	train-rmse:2.96854	eval-rmse:4.50905
# [25]	train-rmse:2.89453	eval-rmse:4.47438
# [26]	train-rmse:2.82766	eval-rmse:4.44807
# [27]	train-rmse:2.77157	eval-rmse:4.43019
# [28]	train-rmse:2.72332	eval-rmse:4.4156
# [29]	train-rmse:2.67321	eval-rmse:4.40181
# [30]	train-rmse:2.62178	eval-rmse:4.38562
# [31]	train-rmse:2.57918	eval-rmse:4.37699
# [32]	train-rmse:2.5444	eval-rmse:4.37007
# [33]	train-rmse:2.51055	eval-rmse:4.36499
# [34]	train-rmse:2.48578	eval-rmse:4.36074
# [35]	train-rmse:2.46231	eval-rmse:4.35641
# [36]	train-rmse:2.44065	eval-rmse:4.35396
# [37]	train-rmse:2.42111	eval-rmse:4.35353
# [38]	train-rmse:2.40483	eval-rmse:4.35199
# [39]	train-rmse:2.38797	eval-rmse:4.35489
# [40]	train-rmse:2.3744	eval-rmse:4.35291
# [41]	train-rmse:2.36301	eval-rmse:4.35599
# [42]	train-rmse:2.34936	eval-rmse:4.35306
# [43]	train-rmse:2.34055	eval-rmse:4.35182
# [44]	train-rmse:2.32619	eval-rmse:4.35142
# [45]	train-rmse:2.31071	eval-rmse:4.35111
# [46]	train-rmse:2.29476	eval-rmse:4.3501
# [47]	train-rmse:2.27763	eval-rmse:4.35025
# [48]	train-rmse:2.26017	eval-rmse:4.35078
# [49]	train-rmse:2.24639	eval-rmse:4.34917
# [50]	train-rmse:2.23363	eval-rmse:4.34884
# [51]	train-rmse:2.22243	eval-rmse:4.34798
# [52]	train-rmse:2.20682	eval-rmse:4.34799
# [53]	train-rmse:2.19543	eval-rmse:4.34875
# [54]	train-rmse:2.1902	eval-rmse:4.34933
# [55]	train-rmse:2.18459	eval-rmse:4.34953
# [56]	train-rmse:2.17989	eval-rmse:4.35041
# [57]	train-rmse:2.16881	eval-rmse:4.3504
# [58]	train-rmse:2.16609	eval-rmse:4.35063
# [59]	train-rmse:2.15947	eval-rmse:4.3514
# [60]	train-rmse:2.15118	eval-rmse:4.3522
# [61]	train-rmse:2.14797	eval-rmse:4.35274
# [62]	train-rmse:2.13409	eval-rmse:4.35389
# [63]	train-rmse:2.12222	eval-rmse:4.35659
# [64]	train-rmse:2.11497	eval-rmse:4.35975
# [65]	train-rmse:2.10302	eval-rmse:4.36021
# [66]	train-rmse:2.09277	eval-rmse:4.36074
# [67]	train-rmse:2.08711	eval-rmse:4.36035
# [68]	train-rmse:2.07913	eval-rmse:4.36111
# [69]	train-rmse:2.06655	eval-rmse:4.36288
# [70]	train-rmse:2.05801	eval-rmse:4.36013
# [71]	train-rmse:2.04967	eval-rmse:4.3601
# [72]	train-rmse:2.04547	eval-rmse:4.3585
# [73]	train-rmse:2.03885	eval-rmse:4.35967
# [74]	train-rmse:2.03386	eval-rmse:4.36125
# [75]	train-rmse:2.02996	eval-rmse:4.36214
# [76]	train-rmse:2.02157	eval-rmse:4.36257
# [77]	train-rmse:2.01641	eval-rmse:4.36052
# [78]	train-rmse:2.01015	eval-rmse:4.35981
# [79]	train-rmse:2.00555	eval-rmse:4.36135
# [80]	train-rmse:2.00036	eval-rmse:4.36099
# [81]	train-rmse:1.98614	eval-rmse:4.35802
# [82]	train-rmse:1.97179	eval-rmse:4.35857
# [83]	train-rmse:1.96089	eval-rmse:4.35794
# [84]	train-rmse:1.95101	eval-rmse:4.3575
# [85]	train-rmse:1.93731	eval-rmse:4.35715
# [86]	train-rmse:1.92496	eval-rmse:4.35856
# [87]	train-rmse:1.91342	eval-rmse:4.35795
# [88]	train-rmse:1.9049	eval-rmse:4.35997
# [89]	train-rmse:1.89559	eval-rmse:4.36046
# [90]	train-rmse:1.88709	eval-rmse:4.36068
# [91]	train-rmse:1.87373	eval-rmse:4.36092
# [92]	train-rmse:1.86549	eval-rmse:4.36109
# [93]	train-rmse:1.85973	eval-rmse:4.3631
# [94]	train-rmse:1.85262	eval-rmse:4.36174
# [95]	train-rmse:1.85035	eval-rmse:4.36127
# [96]	train-rmse:1.83963	eval-rmse:4.35989
# [97]	train-rmse:1.82115	eval-rmse:4.3614
# [98]	train-rmse:1.80422	eval-rmse:4.36421
# [99]	train-rmse:1.79149	eval-rmse:4.36557

# %%
train_metric = evals_result['train']['rmse']
plt.plot(train_metric, label='train rmse')
eval_metric = evals_result['eval']['rmse']
plt.plot(eval_metric, label='eval rmse')
plt.grid()
plt.legend()
plt.xlabel('rounds')
plt.ylabel('rmse')
plt.show()

# %%
d_pred_log = model.predict(d_val)
d_pred = np.exp(d_pred_log)

#plt.plot(d_pred)
plt.figure(figsize=(15,5))
plt.plot(df_val_Y['SalesMansionBkn'].values, label='real')
plt.plot(d_pred, label='pred')
plt.legend()
plt.grid()
plt.show()

# %%
_, ax = plt.subplots(figsize=(15,30))
xgb.plot_importance(model, ax=ax, importance_type='gain')
plt.show()

# %%
m = model.get_score(importance_type='gain')
sorted(m, key=lambda x: m[x], reverse=True)
# Out:
# ['SalesMansionBkn_2',
#  'SalesMansionBkn_3',
#  'SalesMansionBkn_0',
#  'SalesMansionBkn_5',
#  'CategoryId',
#  'SalesMansionBkn_4',
#  'SalesMansionBkn_1',
#  'CampaignId',
#  'Cost_1',
#  'SalesMansionBkn_6',
#  'SalesRent_6',
#  'SalesSck_5',
#  'CpcBid_1',
#  'SalesKodateBkn_5',
#  'SalesKodateBkn_4',
#  'UnitsKodateKen_4',
#  'Cost_5',
#  'UnitsKodateBkn_5',
#  'UnitsSck_5',
#  'SalesKodateBkn_1',
#  'Audience_2',
#  'Audience_6',
#  'CpcBid_5',
#  'SalesSck_0',
#  'Clicks_3',
#  'Cost_6',
#  'UnitsSck_6',
#  'SalesRent_3',
#  'Cost_4',
#  'Cost_2',
#  'UnitsRent_5',
#  'Audience_4',
#  'Cost_3',
#  'SalesMansionKen_1',
#  'UnitsMansionKen_6',
#  'UnitsKodateBkn_2',
#  'SalesKodateKen_1',
#  'Clicks_5',
#  'SalesRyutsu_5',
#  'Audience_3',
#  'UnitsKodateBkn_6',
#  'UnitsKodateBkn_1',
#  'UnitsKodateBkn_3',
#  'CpcBid_2',
#  'Impressions_5',
#  'Impressions_6',
#  'UnitsSck_4',
#  'Audience_5',
#  'Impressions_2',
#  'Reach_4',
#  'Reach_6',
#  'UnitsRent_6',
#  'SalesMansionKen_6',
#  'Reach_3',
#  'SalesRent_4',
#  'SalesSck_1',
#  'Impressions_0',
#  'OverallCompetitionWin_4',
#  'OverallCompetitionWin_6',
#  'SalesMansionKen_0',
#  'Clicks_6',
#  'Cost_0',
#  'Reach_5',
#  'UnitsMansionBkn_6',
#  'Impressions_1',
#  'UnitsRyutsu_6',
#  'SalesRyutsu_2',
#  'Clicks_2',
#  'Impressions_4',
#  'Reach_2',
#  'OverallCompetitionWin_5',
#  'Impressions_3',
#  'SalesKodateKen_2',
#  'SalesRyutsu_6',
#  'SalesRyutsu_1',
#  'UnitsMansionBkn_5',
#  'UnitsRyutsu_4',
#  'UnitsMansionKen_5',
#  'Clicks_4',
#  'SalesKodateBkn_0',
#  'UnitsRent_2',
#  'Reach_1',
#  'UnitsMansionBkn_3',
#  'Clicks_1',
#  'UnitsMansionBkn_2',
#  'CpcBid_4',
#  'UnitsMansionKen_1',
#  'SalesSck_3',
#  'UnitsRent_4',
#  'UnitsRent_3',
#  'UnitsRyutsu_5',
#  'UnitsMansionKen_4',
#  'SalesSck_6',
#  'SalesRent_5',
#  'Clicks_0',
#  'UnitsKodateKen_1',
#  'UnitsKodateKen_3',
#  'UnitsMansionBkn_1',
#  'CpcBid_3',
#  'UnitsKodateBkn_0',
#  'UnitsKodateKen_2',
#  'SalesKodateKen_6',
#  'SalesRent_1',
#  'SalesRent_2',
#  'UnitsRyutsu_3',
#  'UnitsMansionBkn_4',
#  'UnitsRyutsu_1',
#  'UnitsKodateBkn_4',
#  'UnitsRent_1',
#  'CpcBid_6',
#  'UnitsMansionKen_3',
#  'SalesKodateKen_5',
#  'OverallCompetitionWin_2',
#  'OverallCompetitionWin_3',
#  'OverallCompetitionWin_1',
#  'SalesSck_2',
#  'UnitsRyutsu_2',
#  'SalesKodateBkn_6',
#  'SalesRyutsu_3',
#  'SalesMansionKen_5',
#  'Audience_1',
#  'SalesRyutsu_4',
#  'SalesRyutsu_0',
#  'UnitsKodateKen_5',
#  'Reach_0',
#  'UnitsRyutsu_0',
#  'SalesRent_0',
#  'UnitsMansionKen_0',
#  'SalesKodateKen_4',
#  'UnitsMansionBkn_0',
#  'SalesKodateBkn_3',
#  'UnitsRent_0',
#  'UnitsKodateKen_0',
#  'Audience_0',
#  'SalesKodateBkn_2',
#  'UnitsSck_2',
#  'UnitsSck_3',
#  'UnitsMansionKen_2',
#  'SalesMansionKen_2',
#  'CpcBid_0',
#  'UnitsKodateKen_6',
#  'UnitsSck_1',
#  'UnitsSck_0',
#  'MarketId',
#  'SalesSck_4',
#  'SalesKodateKen_3',
#  'OverallCompetitionWin_0',
#  'SalesKodateKen_0',
#  'AdvertiserId']
