# %%
import os
import numpy as np
import pandas as pd

import xgboost as xgb
from sklearn.multioutput import MultiOutputRegressor

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### データ読込

# %%
in_dir = '../data/two_years_each/train_val_skip'

df_train_X = pd.read_excel(os.path.join(in_dir, 'train_X.xlsx'), header=0, index_col=0)
df_train_Y = pd.read_excel(os.path.join(in_dir, 'train_Y.xlsx'), header=0, index_col=0)

df_val_X = pd.read_excel(os.path.join(in_dir, 'val_X.xlsx'), header=0, index_col=0)
df_val_Y = pd.read_excel(os.path.join(in_dir, 'val_Y.xlsx'), header=0, index_col=0)

# %% [markdown]
# ### 目的変数の分布

# %%
sns.distplot(np.log(df_train_Y['SalesRent'] + 0.00000001))
plt.plot()
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# []

# %%
sns.distplot(df_train_Y['SalesRent'], label='train')
sns.distplot(df_val_Y['SalesRent'], label='val')
plt.legend()
plt.plot()
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# []

# %%
def log(x):
    return np.log(x + 0.00000001)

#for c in ['Sales', 'Impressions', 'Clicks', 'Cost']:
for c in ['SalesRent']:
    df_train_Y['SalesRent_log'] = df_train_Y['SalesRent'].apply(log)
    df_val_Y['SalesRent_log'] = df_val_Y['SalesRent'].apply(log)

# %% [markdown]
# ### データ構造転換

# %%
d_train_sales = xgb.DMatrix(df_train_X, label=df_train_Y['SalesRent_log'])
d_val_sales = xgb.DMatrix(df_val_X, label=df_val_Y['SalesRent_log'])

d_val = xgb.DMatrix(df_val_X)
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %% [markdown]
# ### xgboost モデルの作成

# %%
params = {
    'max_depth': 10,
    'learning_rate': 0.1,
    'n_estimators': 1500,
    'objective': 'reg:squarederror',
    'n_jobs': -1,
    'reg_alpha': 10,
    'reg_lambda':10,
}

evals = [(d_train_sales, 'train'), (d_val_sales, 'eval')]
evals_result = {}

model = xgb.train(params, 
          d_train_sales, 
          num_boost_round=100, 
          evals=evals,
          evals_result=evals_result)
# Out:
# [0]	train-rmse:15.8383	eval-rmse:15.3938
# [1]	train-rmse:14.311	eval-rmse:13.939
# [2]	train-rmse:12.9418	eval-rmse:12.6412
# [3]	train-rmse:11.7114	eval-rmse:11.483
# [4]	train-rmse:10.6104	eval-rmse:10.4513
# [5]	train-rmse:9.62136	eval-rmse:9.52975
# [6]	train-rmse:8.73775	eval-rmse:8.71275
# [7]	train-rmse:7.94772	eval-rmse:7.99209
# [8]	train-rmse:7.2401	eval-rmse:7.35757
# [9]	train-rmse:6.60924	eval-rmse:6.79768
# [10]	train-rmse:6.04941	eval-rmse:6.31098
# [11]	train-rmse:5.5513	eval-rmse:5.88355
# [12]	train-rmse:5.10919	eval-rmse:5.51418
# [13]	train-rmse:4.71709	eval-rmse:5.19294
# [14]	train-rmse:4.36986	eval-rmse:4.92067
# [15]	train-rmse:4.06425	eval-rmse:4.68974
# [16]	train-rmse:3.7955	eval-rmse:4.49204
# [17]	train-rmse:3.56188	eval-rmse:4.32825
# [18]	train-rmse:3.35448	eval-rmse:4.18968
# [19]	train-rmse:3.17493	eval-rmse:4.07597
# [20]	train-rmse:3.02046	eval-rmse:3.9814
# [21]	train-rmse:2.88603	eval-rmse:3.90131
# [22]	train-rmse:2.76834	eval-rmse:3.83552
# [23]	train-rmse:2.66207	eval-rmse:3.78163
# [24]	train-rmse:2.57161	eval-rmse:3.73734
# [25]	train-rmse:2.49676	eval-rmse:3.69795
# [26]	train-rmse:2.43054	eval-rmse:3.67064
# [27]	train-rmse:2.36819	eval-rmse:3.64585
# [28]	train-rmse:2.31432	eval-rmse:3.62285
# [29]	train-rmse:2.2709	eval-rmse:3.60543
# [30]	train-rmse:2.22812	eval-rmse:3.59087
# [31]	train-rmse:2.19488	eval-rmse:3.58252
# [32]	train-rmse:2.16001	eval-rmse:3.5754
# [33]	train-rmse:2.12535	eval-rmse:3.56676
# [34]	train-rmse:2.09607	eval-rmse:3.55961
# [35]	train-rmse:2.06838	eval-rmse:3.55144
# [36]	train-rmse:2.05055	eval-rmse:3.54763
# [37]	train-rmse:2.03234	eval-rmse:3.54745
# [38]	train-rmse:2.01503	eval-rmse:3.54602
# [39]	train-rmse:1.99812	eval-rmse:3.54435
# [40]	train-rmse:1.98331	eval-rmse:3.53961
# [41]	train-rmse:1.96619	eval-rmse:3.53694
# [42]	train-rmse:1.94501	eval-rmse:3.53436
# [43]	train-rmse:1.93003	eval-rmse:3.53253
# [44]	train-rmse:1.91861	eval-rmse:3.5318
# [45]	train-rmse:1.90667	eval-rmse:3.5309
# [46]	train-rmse:1.88981	eval-rmse:3.53239
# [47]	train-rmse:1.87485	eval-rmse:3.53138
# [48]	train-rmse:1.86773	eval-rmse:3.53194
# [49]	train-rmse:1.8567	eval-rmse:3.53344
# [50]	train-rmse:1.8482	eval-rmse:3.53309
# [51]	train-rmse:1.83798	eval-rmse:3.53368
# [52]	train-rmse:1.8293	eval-rmse:3.53318
# [53]	train-rmse:1.82081	eval-rmse:3.53439
# [54]	train-rmse:1.81691	eval-rmse:3.53422
# [55]	train-rmse:1.8123	eval-rmse:3.53377
# [56]	train-rmse:1.80593	eval-rmse:3.53424
# [57]	train-rmse:1.80141	eval-rmse:3.53506
# [58]	train-rmse:1.79228	eval-rmse:3.53343
# [59]	train-rmse:1.78517	eval-rmse:3.53395
# [60]	train-rmse:1.78265	eval-rmse:3.5343
# [61]	train-rmse:1.77365	eval-rmse:3.53378
# [62]	train-rmse:1.77073	eval-rmse:3.5343
# [63]	train-rmse:1.76608	eval-rmse:3.53556
# [64]	train-rmse:1.75444	eval-rmse:3.53629
# [65]	train-rmse:1.74783	eval-rmse:3.53576
# [66]	train-rmse:1.73701	eval-rmse:3.53832
# [67]	train-rmse:1.72687	eval-rmse:3.53892
# [68]	train-rmse:1.72124	eval-rmse:3.54103
# [69]	train-rmse:1.71518	eval-rmse:3.54085
# [70]	train-rmse:1.70294	eval-rmse:3.54076
# [71]	train-rmse:1.69623	eval-rmse:3.54033
# [72]	train-rmse:1.68433	eval-rmse:3.53981
# [73]	train-rmse:1.67509	eval-rmse:3.54018
# [74]	train-rmse:1.66674	eval-rmse:3.5405
# [75]	train-rmse:1.65966	eval-rmse:3.54189
# [76]	train-rmse:1.65333	eval-rmse:3.54182
# [77]	train-rmse:1.64407	eval-rmse:3.54296
# [78]	train-rmse:1.63911	eval-rmse:3.54317
# [79]	train-rmse:1.63366	eval-rmse:3.54251
# [80]	train-rmse:1.62684	eval-rmse:3.54364
# [81]	train-rmse:1.62157	eval-rmse:3.54358
# [82]	train-rmse:1.61681	eval-rmse:3.54249
# [83]	train-rmse:1.61065	eval-rmse:3.54304
# [84]	train-rmse:1.6039	eval-rmse:3.54375
# [85]	train-rmse:1.60006	eval-rmse:3.54375
# [86]	train-rmse:1.59261	eval-rmse:3.54355
# [87]	train-rmse:1.58305	eval-rmse:3.54296
# [88]	train-rmse:1.57481	eval-rmse:3.54271
# [89]	train-rmse:1.56883	eval-rmse:3.54161
# [90]	train-rmse:1.5616	eval-rmse:3.54065
# [91]	train-rmse:1.55502	eval-rmse:3.54344
# [92]	train-rmse:1.54541	eval-rmse:3.54509
# [93]	train-rmse:1.53893	eval-rmse:3.54649
# [94]	train-rmse:1.53465	eval-rmse:3.54693
# [95]	train-rmse:1.52824	eval-rmse:3.54737
# [96]	train-rmse:1.52252	eval-rmse:3.54806
# [97]	train-rmse:1.51775	eval-rmse:3.54895
# [98]	train-rmse:1.51286	eval-rmse:3.5488
# [99]	train-rmse:1.50944	eval-rmse:3.54835

# %%
train_metric = evals_result['train']['rmse']
plt.plot(train_metric, label='train rmse')
eval_metric = evals_result['eval']['rmse']
plt.plot(eval_metric, label='eval rmse')
plt.grid()
plt.legend()
plt.xlabel('rounds')
plt.ylabel('rmse')
plt.show()

# %%
d_pred_log = model.predict(d_val)
d_pred = np.exp(d_pred_log)

#plt.plot(d_pred)
plt.figure(figsize=(15,5))
plt.plot(df_val_Y['SalesRent'].values, label='real')
plt.plot(d_pred, label='pred')
plt.legend()
plt.grid()
plt.show()

# %%
_, ax = plt.subplots(figsize=(15,30))
xgb.plot_importance(model, ax=ax, importance_type='gain')
plt.show()

# %%
m = model.get_score(importance_type='gain')
sorted(m, key=lambda x: m[x], reverse=True)
# Out:
# ['SalesRent_0',
#  'SalesRent_2',
#  'SalesRent_3',
#  'MarketId',
#  'SalesRent_1',
#  'SalesRent_4',
#  'Audience_4',
#  'SalesKodateKen_0',
#  'UnitsMansionKen_2',
#  'UnitsMansionKen_3',
#  'Clicks_0',
#  'SalesMansionBkn_0',
#  'SalesSck_4',
#  'SalesRyutsu_1',
#  'SalesKodateKen_1',
#  'SalesSck_1',
#  'SalesRyutsu_4',
#  'SalesKodateBkn_3',
#  'SalesRyutsu_3',
#  'Clicks_1',
#  'SalesKodateBkn_1',
#  'SalesRyutsu_0',
#  'Clicks_4',
#  'Audience_2',
#  'SalesRyutsu_2',
#  'SalesKodateBkn_0',
#  'SalesKodateBkn_4',
#  'SalesMansionBkn_2',
#  'Clicks_2',
#  'Cost_2',
#  'Clicks_3',
#  'Cost_3',
#  'SalesSck_2',
#  'SalesMansionBkn_3',
#  'Cost_0',
#  'UnitsRyutsu_2',
#  'Impressions_3',
#  'OverallCompetitionWin_3',
#  'Reach_3',
#  'Audience_0',
#  'UnitsKodateKen_3',
#  'Cost_4',
#  'Audience_1',
#  'CpcBid_1',
#  'Impressions_0',
#  'CpcBid_4',
#  'Impressions_4',
#  'SalesKodateBkn_2',
#  'OverallCompetitionWin_4',
#  'SalesKodateKen_4',
#  'Reach_2',
#  'UnitsRyutsu_3',
#  'Cost_1',
#  'CpcBid_2',
#  'Audience_3',
#  'Reach_4',
#  'Impressions_1',
#  'SalesMansionBkn_1',
#  'SalesSck_0',
#  'OverallCompetitionWin_2',
#  'UnitsRent_1',
#  'UnitsMansionKen_4',
#  'UnitsKodateBkn_4',
#  'Reach_1',
#  'Impressions_2',
#  'UnitsRent_4',
#  'SalesMansionBkn_4',
#  'CpcBid_3',
#  'SalesSck_3',
#  'UnitsKodateKen_2',
#  'UnitsRent_3',
#  'UnitsRyutsu_4',
#  'UnitsMansionKen_1',
#  'UnitsSck_1',
#  'UnitsSck_4',
#  'Reach_0',
#  'UnitsRent_0',
#  'UnitsMansionBkn_4',
#  'OverallCompetitionWin_1',
#  'UnitsRent_2',
#  'UnitsKodateBkn_3',
#  'UnitsSck_0',
#  'CategoryId',
#  'UnitsRyutsu_1',
#  'UnitsMansionBkn_1',
#  'UnitsMansionBkn_0',
#  'UnitsMansionBkn_2',
#  'UnitsMansionBkn_3',
#  'UnitsKodateBkn_2',
#  'UnitsSck_2',
#  'SalesKodateKen_2',
#  'UnitsSck_3',
#  'UnitsRyutsu_0',
#  'OverallCompetitionWin_0',
#  'UnitsKodateKen_0',
#  'CpcBid_0',
#  'UnitsKodateBkn_1',
#  'UnitsKodateBkn_0',
#  'UnitsKodateKen_4',
#  'UnitsKodateKen_1',
#  'AdvertiserId',
#  'CampaignId',
#  'SalesMansionKen_2',
#  'UnitsMansionKen_0',
#  'SalesKodateKen_3',
#  'SalesMansionKen_0',
#  'SalesMansionKen_4',
#  'SalesMansionKen_3']
