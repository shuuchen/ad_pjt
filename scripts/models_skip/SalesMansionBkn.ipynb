# %%
import os
import numpy as np
import pandas as pd

import xgboost as xgb
from sklearn.multioutput import MultiOutputRegressor

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### データ読込

# %%
in_dir = '../data/two_years_each/train_val_skip'

df_train_X = pd.read_excel(os.path.join(in_dir, 'train_X.xlsx'), header=0, index_col=0)
df_train_Y = pd.read_excel(os.path.join(in_dir, 'train_Y.xlsx'), header=0, index_col=0)

df_val_X = pd.read_excel(os.path.join(in_dir, 'val_X.xlsx'), header=0, index_col=0)
df_val_Y = pd.read_excel(os.path.join(in_dir, 'val_Y.xlsx'), header=0, index_col=0)

# %% [markdown]
# ### 目的変数の分布

# %%
sns.distplot(np.log(df_train_Y['SalesMansionBkn'] + 0.00000001))
plt.plot()

sns.distplot(np.log(df_val_Y['SalesMansionBkn'] + 0.00000001))
plt.plot()
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# []

# %%
sns.distplot(df_train_Y['SalesMansionBkn'], label='train')
sns.distplot(df_val_Y['SalesMansionBkn'], label='val')
plt.legend()
plt.plot()
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# []

# %%
def log(x):
    return np.log(x + 0.00000001)

#for c in ['Sales', 'Impressions', 'Clicks', 'Cost']:
for c in ['SalesMansionBkn']:
    df_train_Y['SalesMansionBkn_log'] = df_train_Y['SalesMansionBkn'].apply(log)
    df_val_Y['SalesMansionBkn_log'] = df_val_Y['SalesMansionBkn'].apply(log)

# %% [markdown]
# ### データ構造転換

# %%
d_train_sales = xgb.DMatrix(df_train_X, label=df_train_Y['SalesMansionBkn_log'])
d_val_sales = xgb.DMatrix(df_val_X, label=df_val_Y['SalesMansionBkn_log'])

d_val = xgb.DMatrix(df_val_X)
# Out:
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\dushu\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %% [markdown]
# ### xgboost モデルの作成

# %%
params = {
    'max_depth': 10,
    'learning_rate': 0.1,
    'n_estimators': 1500,
    'objective': 'reg:squarederror',
    'n_jobs': -1,
    'reg_alpha': 10,
    'reg_lambda':10,
}

evals = [(d_train_sales, 'train'), (d_val_sales, 'eval')]
evals_result = {}

model = xgb.train(params, 
          d_train_sales, 
          num_boost_round=100, 
          evals=evals,
          evals_result=evals_result)
# Out:
# [0]	train-rmse:16.8701	eval-rmse:16.7819
# [1]	train-rmse:15.2529	eval-rmse:15.2267
# [2]	train-rmse:13.8043	eval-rmse:13.8355
# [3]	train-rmse:12.5038	eval-rmse:12.5974
# [4]	train-rmse:11.3406	eval-rmse:11.4977
# [5]	train-rmse:10.2998	eval-rmse:10.5328
# [6]	train-rmse:9.36891	eval-rmse:9.67307
# [7]	train-rmse:8.53773	eval-rmse:8.91895
# [8]	train-rmse:7.7972	eval-rmse:8.25329
# [9]	train-rmse:7.13702	eval-rmse:7.67581
# [10]	train-rmse:6.55327	eval-rmse:7.17881
# [11]	train-rmse:6.03687	eval-rmse:6.74313
# [12]	train-rmse:5.57977	eval-rmse:6.37189
# [13]	train-rmse:5.17755	eval-rmse:6.05652
# [14]	train-rmse:4.82532	eval-rmse:5.78609
# [15]	train-rmse:4.51171	eval-rmse:5.55557
# [16]	train-rmse:4.23831	eval-rmse:5.3602
# [17]	train-rmse:3.99687	eval-rmse:5.19469
# [18]	train-rmse:3.78618	eval-rmse:5.0595
# [19]	train-rmse:3.60243	eval-rmse:4.94943
# [20]	train-rmse:3.44026	eval-rmse:4.85485
# [21]	train-rmse:3.30223	eval-rmse:4.78386
# [22]	train-rmse:3.17975	eval-rmse:4.72584
# [23]	train-rmse:3.07937	eval-rmse:4.67829
# [24]	train-rmse:2.98392	eval-rmse:4.63494
# [25]	train-rmse:2.90724	eval-rmse:4.60295
# [26]	train-rmse:2.83973	eval-rmse:4.57664
# [27]	train-rmse:2.77591	eval-rmse:4.55785
# [28]	train-rmse:2.72727	eval-rmse:4.54361
# [29]	train-rmse:2.68453	eval-rmse:4.53291
# [30]	train-rmse:2.63957	eval-rmse:4.52489
# [31]	train-rmse:2.60408	eval-rmse:4.51831
# [32]	train-rmse:2.57351	eval-rmse:4.51029
# [33]	train-rmse:2.54442	eval-rmse:4.50728
# [34]	train-rmse:2.52206	eval-rmse:4.50368
# [35]	train-rmse:2.50053	eval-rmse:4.4987
# [36]	train-rmse:2.48366	eval-rmse:4.49604
# [37]	train-rmse:2.46802	eval-rmse:4.49379
# [38]	train-rmse:2.45892	eval-rmse:4.49367
# [39]	train-rmse:2.44776	eval-rmse:4.49309
# [40]	train-rmse:2.44222	eval-rmse:4.49176
# [41]	train-rmse:2.43496	eval-rmse:4.49128
# [42]	train-rmse:2.42679	eval-rmse:4.49202
# [43]	train-rmse:2.42092	eval-rmse:4.4924
# [44]	train-rmse:2.41687	eval-rmse:4.4919
# [45]	train-rmse:2.40841	eval-rmse:4.49029
# [46]	train-rmse:2.39375	eval-rmse:4.4873
# [47]	train-rmse:2.38701	eval-rmse:4.48696
# [48]	train-rmse:2.38052	eval-rmse:4.48876
# [49]	train-rmse:2.3729	eval-rmse:4.48989
# [50]	train-rmse:2.35795	eval-rmse:4.48671
# [51]	train-rmse:2.34151	eval-rmse:4.4839
# [52]	train-rmse:2.3228	eval-rmse:4.48619
# [53]	train-rmse:2.31427	eval-rmse:4.48669
# [54]	train-rmse:2.30978	eval-rmse:4.48829
# [55]	train-rmse:2.29557	eval-rmse:4.48688
# [56]	train-rmse:2.28594	eval-rmse:4.48963
# [57]	train-rmse:2.28021	eval-rmse:4.48972
# [58]	train-rmse:2.26739	eval-rmse:4.49002
# [59]	train-rmse:2.26098	eval-rmse:4.49038
# [60]	train-rmse:2.2523	eval-rmse:4.49024
# [61]	train-rmse:2.24084	eval-rmse:4.48706
# [62]	train-rmse:2.22743	eval-rmse:4.48617
# [63]	train-rmse:2.22012	eval-rmse:4.48689
# [64]	train-rmse:2.20611	eval-rmse:4.48527
# [65]	train-rmse:2.20229	eval-rmse:4.48528
# [66]	train-rmse:2.19231	eval-rmse:4.4842
# [67]	train-rmse:2.17799	eval-rmse:4.48557
# [68]	train-rmse:2.17111	eval-rmse:4.48663
# [69]	train-rmse:2.16709	eval-rmse:4.48627
# [70]	train-rmse:2.15621	eval-rmse:4.48426
# [71]	train-rmse:2.1483	eval-rmse:4.48585
# [72]	train-rmse:2.13508	eval-rmse:4.48407
# [73]	train-rmse:2.12703	eval-rmse:4.48565
# [74]	train-rmse:2.1098	eval-rmse:4.48577
# [75]	train-rmse:2.10445	eval-rmse:4.48499
# [76]	train-rmse:2.10117	eval-rmse:4.48518
# [77]	train-rmse:2.09389	eval-rmse:4.48508
# [78]	train-rmse:2.08639	eval-rmse:4.48634
# [79]	train-rmse:2.08186	eval-rmse:4.4865
# [80]	train-rmse:2.07725	eval-rmse:4.48649
# [81]	train-rmse:2.06821	eval-rmse:4.48641
# [82]	train-rmse:2.06205	eval-rmse:4.48696
# [83]	train-rmse:2.05855	eval-rmse:4.48653
# [84]	train-rmse:2.04978	eval-rmse:4.4876
# [85]	train-rmse:2.04248	eval-rmse:4.48566
# [86]	train-rmse:2.03387	eval-rmse:4.485
# [87]	train-rmse:2.02523	eval-rmse:4.48613
# [88]	train-rmse:2.01103	eval-rmse:4.48496
# [89]	train-rmse:2.00269	eval-rmse:4.4848
# [90]	train-rmse:1.99028	eval-rmse:4.48744
# [91]	train-rmse:1.9825	eval-rmse:4.48855
# [92]	train-rmse:1.96835	eval-rmse:4.48871
# [93]	train-rmse:1.95484	eval-rmse:4.48609
# [94]	train-rmse:1.94235	eval-rmse:4.48783
# [95]	train-rmse:1.93397	eval-rmse:4.48844
# [96]	train-rmse:1.91848	eval-rmse:4.48611
# [97]	train-rmse:1.91186	eval-rmse:4.48635
# [98]	train-rmse:1.89538	eval-rmse:4.48531
# [99]	train-rmse:1.88875	eval-rmse:4.48673

# %%
train_metric = evals_result['train']['rmse']
plt.plot(train_metric, label='train rmse')
eval_metric = evals_result['eval']['rmse']
plt.plot(eval_metric, label='eval rmse')
plt.grid()
plt.legend()
plt.xlabel('rounds')
plt.ylabel('rmse')
plt.show()

# %%
d_pred_log = model.predict(d_val)
d_pred = np.exp(d_pred_log)

#plt.plot(d_pred)
plt.figure(figsize=(15,5))
plt.plot(df_val_Y['SalesMansionBkn'].values, label='real')
plt.plot(d_pred, label='pred')
plt.legend()
plt.grid()
plt.show()

# %%
_, ax = plt.subplots(figsize=(15,30))
xgb.plot_importance(model, ax=ax, importance_type='gain')
plt.show()

# %%
m = model.get_score(importance_type='gain')
sorted(m, key=lambda x: m[x], reverse=True)
# Out:
# ['SalesMansionBkn_0',
#  'SalesMansionBkn_3',
#  'SalesMansionBkn_1',
#  'CampaignId',
#  'CategoryId',
#  'SalesMansionKen_4',
#  'SalesMansionBkn_2',
#  'SalesRyutsu_0',
#  'SalesRent_1',
#  'SalesSck_0',
#  'UnitsRent_4',
#  'CpcBid_4',
#  'SalesRent_4',
#  'SalesKodateBkn_1',
#  'Cost_3',
#  'Cost_2',
#  'SalesSck_3',
#  'Cost_0',
#  'Reach_4',
#  'UnitsRent_3',
#  'SalesRent_0',
#  'Audience_4',
#  'UnitsKodateKen_4',
#  'Clicks_3',
#  'Clicks_4',
#  'SalesKodateKen_4',
#  'UnitsRyutsu_3',
#  'Clicks_0',
#  'Cost_4',
#  'SalesKodateBkn_3',
#  'Impressions_4',
#  'SalesRent_3',
#  'Clicks_2',
#  'UnitsMansionKen_3',
#  'UnitsKodateKen_3',
#  'Cost_1',
#  'Reach_1',
#  'Reach_3',
#  'CpcBid_1',
#  'Audience_2',
#  'SalesSck_2',
#  'Impressions_3',
#  'Audience_3',
#  'OverallCompetitionWin_3',
#  'Impressions_0',
#  'SalesRyutsu_4',
#  'OverallCompetitionWin_4',
#  'UnitsKodateBkn_4',
#  'SalesSck_4',
#  'UnitsRyutsu_4',
#  'UnitsMansionBkn_4',
#  'UnitsKodateBkn_0',
#  'SalesMansionBkn_4',
#  'Impressions_1',
#  'UnitsRyutsu_1',
#  'SalesRyutsu_3',
#  'Reach_0',
#  'Clicks_1',
#  'UnitsRent_2',
#  'CpcBid_2',
#  'SalesKodateKen_0',
#  'SalesRyutsu_2',
#  'UnitsRent_1',
#  'SalesRent_2',
#  'UnitsMansionKen_4',
#  'Impressions_2',
#  'SalesSck_1',
#  'UnitsMansionBkn_3',
#  'Reach_2',
#  'SalesKodateBkn_4',
#  'UnitsMansionBkn_2',
#  'SalesKodateKen_2',
#  'UnitsSck_1',
#  'UnitsSck_4',
#  'UnitsMansionKen_2',
#  'SalesKodateBkn_2',
#  'Audience_1',
#  'UnitsRyutsu_2',
#  'UnitsKodateKen_2',
#  'SalesMansionKen_0',
#  'UnitsSck_3',
#  'OverallCompetitionWin_2',
#  'UnitsKodateBkn_3',
#  'CpcBid_0',
#  'CpcBid_3',
#  'UnitsRyutsu_0',
#  'SalesKodateKen_1',
#  'UnitsSck_2',
#  'SalesRyutsu_1',
#  'UnitsKodateBkn_2',
#  'OverallCompetitionWin_1',
#  'UnitsMansionKen_1',
#  'UnitsMansionKen_0',
#  'UnitsSck_0',
#  'UnitsKodateKen_1',
#  'UnitsMansionBkn_1',
#  'UnitsKodateBkn_1',
#  'UnitsRent_0',
#  'SalesKodateBkn_0',
#  'OverallCompetitionWin_0',
#  'UnitsMansionBkn_0',
#  'Audience_0',
#  'UnitsKodateKen_0',
#  'MarketId',
#  'SalesMansionKen_3',
#  'SalesMansionKen_2',
#  'AdvertiserId',
#  'SalesKodateKen_3',
#  'SalesMansionKen_1']
